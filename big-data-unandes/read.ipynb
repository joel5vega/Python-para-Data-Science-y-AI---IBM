# %%
import pandas as pd

# %%
parquet_file_2009= "data/yellow_tripdata_2009-01.parquet"
parquet_file_2013= "data/yellow_tripdata_2013-01.parquet"
parquet_file_2019= "data/yellow_tripdata_2019-01.parquet"
parquet_file="data/"

# %%
pd.read_parquet(parquet_file,engine='auto')
# Out:
#          vendor_name Trip_Pickup_DateTime Trip_Dropoff_DateTime  \
# 0                VTS  2009-01-04 02:52:00   2009-01-04 03:02:00
# 1                VTS  2009-01-04 03:31:00   2009-01-04 03:38:00
# 2                VTS  2009-01-03 15:43:00   2009-01-03 15:57:00
# 3                DDS  2009-01-01 20:52:58   2009-01-01 21:14:00
# 4                DDS  2009-01-24 16:18:23   2009-01-24 16:24:56
# ...              ...                  ...                   ...
# 36565642        None                 None                  None
# 36565643        None                 None                  None
# 36565644        None                 None                  None
# 36565645        None                 None                  None
# 36565646        None                 None                  None
#
#           Passenger_Count  Trip_Distance  Start_Lon  Start_Lat  Rate_Code  \
# 0                     1.0           2.63 -73.991957  40.721567        NaN
# ...

# %%
df.head()
